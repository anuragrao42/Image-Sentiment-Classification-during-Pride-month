# %%
import os
import glob
import path

# %%
import pandas as pd

# %%
import numpy as np

# %%
import re

# %%
from PIL import Image

# %%
import pytesseract

# %%
base_dir = os.path.join(r'C:\Users\Anurag\Desktop\dataset\hackr quote anal\Data Files')

# %%
img_files = os.path.join(base_dir, 'Dataset')

# %%
imgs_file = glob.glob(img_files+'/*.jpg')

# %%
test_files =  pd.read_csv(r'C:\Users\Anurag\Desktop\dataset\hackr quote anal\Data Files\Test.csv')

# %%
X_test = test_files['Filename'].values

# %%
X_test
# Out:
# array(['Test1001.jpg', 'Test1012.jpg', 'Test1022.jpg', 'Test1071.jpg',
#        'Test1122.jpg', 'Test1161.jpg', 'Test1199.jpg', 'Test1229.jpg',
#        'Test1240.jpg', 'Test1271.jpg', 'Test1279.jpg', 'Test1290.jpg',
#        'Test1353.jpg', 'Test1359.jpg', 'Test1615.jpg', 'Test1620.jpg',
#        'Test1634.jpg', 'Test1644.jpg', 'Test1717.jpg', 'Test1724.jpg',
#        'Test1743.jpg', 'Test1767.jpg', 'Test1776.jpg', 'Test1785.jpg',
#        'Test1788.jpg', 'Test1803.jpg', 'Test1818.jpg', 'Test1837.jpg',
#        'Test1856.jpg', 'Test1872.jpg', 'Test1884.jpg', 'Test1885.jpg',
#        'Test1889.jpg', 'Test1902.jpg', 'Test1923.jpg', 'Test1934.jpg',
#        'Test1954.jpg', 'Test1992.jpg', 'Test2007.jpg', 'Test2049.jpg',
#        'Test2068.jpg', 'Test2114.jpg', 'Test2209.jpg', 'Test2235.jpg',
#        'Test2280.jpg', 'Test2309.jpg', 'Test2371.jpg', 'Test2411.jpg',
#        'Test2424.jpg', 'Test2434.jpg', 'Test2455.jpg', 'Test2590.jpg',
# ...

# %%
files
# Out:
# ['C:\\Users\\Anurag\\Desktop\\dataset\\hackr quote anal\\Data Files\\Dataset\\Test100.jpg',
#  'C:\\Users\\Anurag\\Desktop\\dataset\\hackr quote anal\\Data Files\\Dataset\\Test103.jpg',
#  'C:\\Users\\Anurag\\Desktop\\dataset\\hackr quote anal\\Data Files\\Dataset\\Test105.jpg',
#  'C:\\Users\\Anurag\\Desktop\\dataset\\hackr quote anal\\Data Files\\Dataset\\Test107.jpg',
#  'C:\\Users\\Anurag\\Desktop\\dataset\\hackr quote anal\\Data Files\\Dataset\\Test108.jpg',
#  'C:\\Users\\Anurag\\Desktop\\dataset\\hackr quote anal\\Data Files\\Dataset\\Test109.jpg',
#  'C:\\Users\\Anurag\\Desktop\\dataset\\hackr quote anal\\Data Files\\Dataset\\Test113.jpg',
#  'C:\\Users\\Anurag\\Desktop\\dataset\\hackr quote anal\\Data Files\\Dataset\\Test114.jpg',
#  'C:\\Users\\Anurag\\Desktop\\dataset\\hackr quote anal\\Data Files\\Dataset\\Test117.jpg',
#  'C:\\Users\\Anurag\\Desktop\\dataset\\hackr quote anal\\Data Files\\Dataset\\Test119.jpg',
# ...

# %%
imgs_file.sort()

# %%
imgs_file
# Out:
# ['C:\\Users\\Anurag\\Desktop\\dataset\\hackr quote anal\\Data Files\\Dataset\\Test100.jpg',
#  'C:\\Users\\Anurag\\Desktop\\dataset\\hackr quote anal\\Data Files\\Dataset\\Test1001.jpg',
#  'C:\\Users\\Anurag\\Desktop\\dataset\\hackr quote anal\\Data Files\\Dataset\\Test1012.jpg',
#  'C:\\Users\\Anurag\\Desktop\\dataset\\hackr quote anal\\Data Files\\Dataset\\Test1022.jpg',
#  'C:\\Users\\Anurag\\Desktop\\dataset\\hackr quote anal\\Data Files\\Dataset\\Test103.jpg',
#  'C:\\Users\\Anurag\\Desktop\\dataset\\hackr quote anal\\Data Files\\Dataset\\Test105.jpg',
#  'C:\\Users\\Anurag\\Desktop\\dataset\\hackr quote anal\\Data Files\\Dataset\\Test107.jpg',
#  'C:\\Users\\Anurag\\Desktop\\dataset\\hackr quote anal\\Data Files\\Dataset\\Test1071.jpg',
#  'C:\\Users\\Anurag\\Desktop\\dataset\\hackr quote anal\\Data Files\\Dataset\\Test108.jpg',
#  'C:\\Users\\Anurag\\Desktop\\dataset\\hackr quote anal\\Data Files\\Dataset\\Test109.jpg',
# ...

# %%
texts = []

# %%
len(imgs_file)
# Out:
# 239

# %%
pytesseract.pytesseract.tesseract_cmd = r'C:\Program Files\Tesseract-OCR\tesseract.exe'

# %%
img = Image.open(imgs_file[1])

# %%
text = pytesseract.image_to_string(img)

# %%
text
# Out:
# "When people ask\nwhat I see in you,\nI just smile and\nlook away because\nI'm afraid if they knew,\nthey'd fall in love\nwith you too."

# %%
for imgs in X_test:
    img = Image.open('C:\\Users\\Anurag\\Desktop\\dataset\\hackr quote anal\\Data Files\\Dataset\\'+imgs)
    text = pytesseract.image_to_string(img)
    review = re.sub('[^a-zA-Z]', ' ', text)
    review = review.lower()
    
    texts.append(review)

# %%
for imgs in imgs_file:
    img = Image.open(imgs)
    text = pytesseract.image_to_string(img)
    review = re.sub('[^a-zA-Z]', ' ', text)
    review = review.lower()
    
    texts.append(review)

# %%
len(texts)
# Out:
# 239

# %%
texts
# Out:
# ['when people ask what i see in you  i just smile and look away because i m afraid if they knew  they d fall in love with you too ',
#  'es smee    aie  al ree',
#  'love  ',
#  'ees mu walla ol  em eae ie  not living by society s standards  but deep down  they wish they had the courage to do the same   we being gay   proud quotes www geckoandfly com  se',
#  ' zeigler  author of  fair play  how lgbt athletes are claiming their rightful place in sports   defied the motion that sports are inberemty homophobic  part of what is keeping gay athletes closeted  zeigher said  iy the hyper heteromeninm that exists in locket roams  negative talk about bay people isnot the iste  instead  i s the demeaning talk about women ',
#  '',
# ...

# %%
txtx = np.array(texts)

# %%
txtx.shape
# Out:
# (239,)

# %%
submission = pd.DataFrame({ 'Category':  txtx })
submission.to_csv('new_textss.csv', index=False)

# %%
submission = pd.DataFrame({ 'Filename':  txtx })
submission.to_csv('filenames.csv', index=False)

# %%
imgs_file
# Out:
# ['C:\\Users\\Anurag\\Desktop\\dataset\\hackr quote anal\\Data Files\\Dataset\\Test100.jpg',
#  'C:\\Users\\Anurag\\Desktop\\dataset\\hackr quote anal\\Data Files\\Dataset\\Test1001.jpg',
#  'C:\\Users\\Anurag\\Desktop\\dataset\\hackr quote anal\\Data Files\\Dataset\\Test1012.jpg',
#  'C:\\Users\\Anurag\\Desktop\\dataset\\hackr quote anal\\Data Files\\Dataset\\Test1022.jpg',
#  'C:\\Users\\Anurag\\Desktop\\dataset\\hackr quote anal\\Data Files\\Dataset\\Test103.jpg',
#  'C:\\Users\\Anurag\\Desktop\\dataset\\hackr quote anal\\Data Files\\Dataset\\Test105.jpg',
#  'C:\\Users\\Anurag\\Desktop\\dataset\\hackr quote anal\\Data Files\\Dataset\\Test107.jpg',
#  'C:\\Users\\Anurag\\Desktop\\dataset\\hackr quote anal\\Data Files\\Dataset\\Test1071.jpg',
#  'C:\\Users\\Anurag\\Desktop\\dataset\\hackr quote anal\\Data Files\\Dataset\\Test108.jpg',
#  'C:\\Users\\Anurag\\Desktop\\dataset\\hackr quote anal\\Data Files\\Dataset\\Test109.jpg',
# ...
